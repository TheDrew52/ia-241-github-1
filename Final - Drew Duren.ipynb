# %% [markdown]
# # Covid Cases Mozambique - Drew Duren

# %% [markdown]
# # Inputting the Data

# %%
# %matplotlib inline
import pandas

# %%
df = pandas.read_excel('s3://ia241-1-spring2022-drew/covid_data.xls')
df[:39301]
# Out:
#                    dateRep  day  month  year  cases  deaths  \
# 0               14/12/2020   14     12  2020    746       6
# 1               13/12/2020   13     12  2020    298       9
# 2      2020-12-12 00:00:00   12     12  2020    113      11
# 3      2020-11-12 00:00:00   11     12  2020     63      10
# 4      2020-10-12 00:00:00   10     12  2020    202      16
# ...                    ...  ...    ...   ...    ...     ...
# 39296           25/03/2020   25      3  2020      0       0
# 39297           24/03/2020   24      3  2020      0       0
# 39298           23/03/2020   23      3  2020      1       0
# 39299           14/12/2020   14     12  2020   1127      23
# 39300           13/12/2020   13     12  2020   1352      25
#
#       countriesAndTerritories geoId countryterritoryCode  popData2019  \
# 0                 Afghanistan    AF                  AFG   38041757.0
# 1                 Afghanistan    AF                  AFG   38041757.0
# ...

# %% [markdown]
# # Mozambique Data

# %%
sum_cases = df.groupby('dateRep').sum()['cases']

# %%
Moz_data = df.loc[ df['countriesAndTerritories']=='Mozambique' ]
Moz_data[:10]
# Out:
#                    dateRep  day  month  year  cases  deaths  \
# 39032           14/12/2020   14     12  2020    142       2
# 39033           13/12/2020   13     12  2020    132       1
# 39034  2020-12-12 00:00:00   12     12  2020    159       0
# 39035  2020-11-12 00:00:00   11     12  2020     81       1
# 39036  2020-10-12 00:00:00   10     12  2020     67       2
# 39037  2020-09-12 00:00:00    9     12  2020     47       0
# 39038  2020-08-12 00:00:00    8     12  2020     82       3
# 39039  2020-07-12 00:00:00    7     12  2020    111       0
# 39040  2020-06-12 00:00:00    6     12  2020     95       0
# 39041  2020-05-12 00:00:00    5     12  2020    120       1
#
#       countriesAndTerritories geoId countryterritoryCode  popData2019  \
# 39032              Mozambique    MZ                  MOZ   30366043.0
# 39033              Mozambique    MZ                  MOZ   30366043.0
# 39034              Mozambique    MZ                  MOZ   30366043.0
# ...

# %%
Mozambique_data = df[39034:39300]

# %% [markdown]
# # What are the months with the highest COVID cases in Mozambique?

# %%
Mozambique_Data_Plot.plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# # What are the sum number of cases per month in Mozambique?

# %%
Mozambique_sum_cases = Mozambique_data.groupby('month').sum()['cases']

# %%
Mozambique_sum_cases.plot.bar()
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# # How is the number of cases related to the number of deaths within Mozambique?

# %%
Mozambique_data.plot.scatter(x='cases',y='deaths',c='month')
# Out:
# <AxesSubplot:xlabel='cases', ylabel='deaths'>
